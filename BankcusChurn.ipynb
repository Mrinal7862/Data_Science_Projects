# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("barelydedicated/bank-customer-churn-modeling")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\dell\.cache\kagglehub\datasets\barelydedicated\bank-customer-churn-modeling\versions\1

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from tensorflow import keras
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df["Exited"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
df['Geography'].describe()
# Out:
# count      10000
# unique         3
# top       France
# freq        5014
# Name: Geography, dtype: object

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.Gender
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 9995      Male
# 9996      Male
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender, Length: 10000, dtype: str

# %%
df["Gender"] = df["Gender"].replace({"Male":0, "Female":1})

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 0             1    15634602   Hargrave          619    France      1   42
# 1             2    15647311       Hill          608     Spain      1   41
# 2             3    15619304       Onio          502    France      1   42
# 3             4    15701354       Boni          699    France      1   39
# 4             5    15737888   Mitchell          850     Spain      1   43
# ...         ...         ...        ...          ...       ...    ...  ...
# 9995       9996    15606229   Obijiaku          771    France      0   39
# 9996       9997    15569892  Johnstone          516    France      0   35
# 9997       9998    15584532        Liu          709    France      1   36
# 9998       9999    15682355  Sabbatini          772   Germany      0   42
# 9999      10000    15628319     Walker          792    France      1   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Gender'] = df['Gender'].astype("int64")

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender               int64
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.Geography.unique()
# Out:
# <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str

# %%
df = pd.get_dummies(df, columns=['Geography'], drop_first=True, dtype='int64')

# %%
df.dtypes
# Out:
# RowNumber              int64
# CustomerId             int64
# Surname                  str
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geography_Germany', 'Geography_Spain'],
#       dtype='str')

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis="columns", inplace=True)

# %%
df
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       1   42       2       0.00              1          1
# 1             608       1   41       1   83807.86              1          0
# 2             502       1   42       8  159660.80              3          1
# 3             699       1   39       1       0.00              2          0
# 4             850       1   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       0   39       5       0.00              2          1
# 9996          516       0   35      10   57369.61              1          1
# 9997          709       1   36       7       0.00              1          0
# 9998          772       0   42       3   75075.31              2          1
# 9999          792       1   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 12 columns]

# %%
df.dtypes
# Out:
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %%
df.Exited
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,random_state=42, stratify=y)

# %%
X_train.shape
# Out:
# (7500, 11)

# %%
y_train.shape
# Out:
# (7500,)

# %%
X_test
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 2605          635       1   34       5   98683.47              2          1
# 9717          757       0   30       3  145396.49              1          0
# 68            661       1   35       5  150725.53              2          0
# 9397          766       1   52       7   92510.90              2          0
# 4004          530       1   41       4       0.00              2          0
# ...           ...     ...  ...     ...        ...            ...        ...
# 246           772       0   26       7  152400.51              2          1
# 2538          723       0   38       6       0.00              2          1
# 5018          556       1   51       8   61354.14              1          1
# 4536          642       1   55       7       0.00              2          1
# 7423          699       0   36       2  123601.56              2          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain
# 2605               0         15733.19                  0                1
# 9717               1        198341.15                  0                1
# 68                 1        113656.85                  1                0
# 9397               1         66193.61                  0                0
# 4004               1        147606.71                  0                1
# ...              ...              ...                ...              ...
# 246                0         79414.00                  1                0
# 2538               1         94415.60                  0                1
# 5018               0        198810.65                  0                0
# 4536               1        101515.76                  0                0
# 7423               0        103557.85                  1                0
#
# [2500 rows x 11 columns]

# %%
history.history.keys
# Out:
# <function dict.keys()>

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (7500, 11)

# %%
model = keras.Sequential([
    keras.layers.Dense(11, input_shape=(X_train.shape[1],), activation='relu'),
    keras.layers.Dense(11, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    validation_split=0.2
)
# Out:
# C:\Users\dell\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6938 - loss: 0.5977 - val_accuracy: 0.8080 - val_loss: 0.4760
# Epoch 2/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7948 - loss: 0.4609 - val_accuracy: 0.8093 - val_loss: 0.4351
# Epoch 3/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8043 - loss: 0.4324 - val_accuracy: 0.8247 - val_loss: 0.4140
# Epoch 4/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8208 - loss: 0.4117 - val_accuracy: 0.8373 - val_loss: 0.3965
# Epoch 5/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8333 - loss: 0.3955 - val_accuracy: 0.8460 - val_loss: 0.3834
# Epoch 6/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8417 - loss: 0.3832 - val_accuracy: 0.8507 - val_loss: 0.3717
# Epoch 7/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8463 - loss: 0.3732 - val_accuracy: 0.8467 - val_loss: 0.3660
# Epoch 8/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8518 - loss: 0.3668 - val_accuracy: 0.8580 - val_loss: 0.3575
# Epoch 9/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8545 - loss: 0.3622 - val_accuracy: 0.8573 - val_loss: 0.3538
# Epoch 10/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8555 - loss: 0.3575 - val_accuracy: 0.8673 - val_loss: 0.3513
# Epoch 11/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8545 - loss: 0.3556 - val_accuracy: 0.8633 - val_loss: 0.3482
# Epoch 12/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8552 - loss: 0.3528 - val_accuracy: 0.8600 - val_loss: 0.3475
# Epoch 13/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.
100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8628 - loss: 0.3262 - val_accuracy: 0.8653 - val_loss: 0.3466
# Epoch 78/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8623 - loss: 0.3255 - val_accuracy: 0.8620 - val_loss: 0.3467
# Epoch 79/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8640 - loss: 0.3254 - val_accuracy: 0.8627 - val_loss: 0.3477
# Epoch 80/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8632 - loss: 0.3248 - val_accuracy: 0.8620 - val_loss: 0.3477
# Epoch 81/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8637 - loss: 0.3240 - val_accuracy: 0.8573 - val_loss: 0.3483
# Epoch 82/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8650 - loss: 0.3250 - val_accuracy: 0.8593 - val_loss: 0.3488
# Epoch 83/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8645 - loss: 0.3247 - val_accuracy: 0.8607 - val_loss: 0.3496
# Epoch 84/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8642 - loss: 0.3244 - val_accuracy: 0.8627 - val_loss: 0.3501
# Epoch 85/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8655 - loss: 0.3253 - val_accuracy: 0.8587 - val_loss: 0.3491
# Epoch 86/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8642 - loss: 0.3241 - val_accuracy: 0.8580 - val_loss: 0.3486
# Epoch 87/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8632 - loss: 0.3241 - val_accuracy: 0.8580 - val_loss: 0.3486
# Epoch 88/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8653 - loss: 0.3239 - val_accuracy: 0.8600 - val_loss: 0.3494
# Epoch 89/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8635 - loss: 0.3238 - val_accuracy: 0.8580 - val_loss: 0.3491
# Epoch 90/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8648 - loss: 0.3238 - val_accuracy: 0.8640 - val_loss: 0.3477
# Epoch 91/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - loss: 0.3244 - val_accuracy: 0.8587 - val_loss: 0.3490
# Epoch 92/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8628 - loss: 0.3236 - val_accuracy: 0.8620 - val_loss: 0.3494
# Epoch 93/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8637 - loss: 0.3234 - val_accuracy: 0.8620 - val_loss: 0.3489
# Epoch 94/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8642 - loss: 0.3243 - val_accuracy: 0.8627 - val_loss: 0.3484
# Epoch 95/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8640 - loss: 0.3235 - val_accuracy: 0.8620 - val_loss: 0.3504
# Epoch 96/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8650 - loss: 0.3231 - val_accuracy: 0.8627 - val_loss: 0.3485
# Epoch 97/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8645 - loss: 0.3237 - val_accuracy: 0.8607 - val_loss: 0.3492
# Epoch 98/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8622 - loss: 0.3236 - val_accuracy: 0.8607 - val_loss: 0.3484
# Epoch 99/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8638 - loss: 0.3230 - val_accuracy: 0.8627 - val_loss: 0.3473
# Epoch 100/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8640 - loss: 0.3232 - val_accuracy: 0.8607 - val_loss: 0.3505

# %%
model.evaluate(X_test, y_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8596 - loss: 0.3355
# [0.33547860383987427, 0.8596000075340271]

# %%
y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5).astype(int)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_test
# Out:
# 2605    0
# 9717    0
# 68      0
# 9397    0
# 4004    0
#        ..
# 246     0
# 2538    0
# 5018    1
# 4536    0
# 7423    0
# Name: Exited, Length: 2500, dtype: int64

# %% [raw]
# print(y_pred)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1898   93]
#  [ 258  251]]

# %%
sns.heatmap(cm , annot=True, fmt='d', cmap='Blues', xticklabels=['Not churn', 'Churn'], yticklabels=['Not churn', 'Churn'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.92      1991
#            1       0.73      0.49      0.59       509
#
#     accuracy                           0.86      2500
#    macro avg       0.80      0.72      0.75      2500
# weighted avg       0.85      0.86      0.85      2500

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Train', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
