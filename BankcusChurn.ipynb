# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("barelydedicated/bank-customer-churn-modeling")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\dell\.cache\kagglehub\datasets\barelydedicated\bank-customer-churn-modeling\versions\1

# %%
import pandas as pd 
import numpy as np 
import tensorflow as tf 
from tensorflow import keras
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df["Exited"]
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='str')

# %%
df['Geography'].describe()
# Out:
# count      10000
# unique         3
# top       France
# freq        5014
# Name: Geography, dtype: object

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender                 str
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.Gender
# Out:
# 0       Female
# 1       Female
# 2       Female
# 3       Female
# 4       Female
#          ...
# 9995      Male
# 9996      Male
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender, Length: 10000, dtype: str

# %%
df["Gender"] = df["Gender"].replace({"Male":0, "Female":1})

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography Gender  Age  \
# 0             1    15634602   Hargrave          619    France      1   42
# 1             2    15647311       Hill          608     Spain      1   41
# 2             3    15619304       Onio          502    France      1   42
# 3             4    15701354       Boni          699    France      1   39
# 4             5    15737888   Mitchell          850     Spain      1   43
# ...         ...         ...        ...          ...       ...    ...  ...
# 9995       9996    15606229   Obijiaku          771    France      0   39
# 9996       9997    15569892  Johnstone          516    France      0   35
# 9997       9998    15584532        Liu          709    France      1   36
# 9998       9999    15682355  Sabbatini          772   Germany      0   42
# 9999      10000    15628319     Walker          792    France      1   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df['Gender'] = df['Gender'].astype("int64")

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname                str
# CreditScore          int64
# Geography              str
# Gender               int64
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
df.Geography.unique()
# Out:
# <StringArray>
# ['France', 'Spain', 'Germany']
# Length: 3, dtype: str

# %%
df = pd.get_dummies(df, columns=['Geography'], drop_first=True, dtype='int64')

# %%
df.dtypes
# Out:
# RowNumber              int64
# CustomerId             int64
# Surname                  str
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited', 'Geography_Germany', 'Geography_Spain'],
#       dtype='str')

# %%
df.drop(['RowNumber', 'CustomerId', 'Surname'], axis="columns", inplace=True)

# %%
df
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       1   42       2       0.00              1          1
# 1             608       1   41       1   83807.86              1          0
# 2             502       1   42       8  159660.80              3          1
# 3             699       1   39       1       0.00              2          0
# 4             850       1   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       0   39       5       0.00              2          1
# 9996          516       0   35      10   57369.61              1          1
# 9997          709       1   36       7       0.00              1          0
# 9998          772       0   42       3   75075.31              2          1
# 9999          792       1   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# 1                  1        112542.58       0                  0
# 2                  0        113931.57       1                  0
# 3                  0         93826.63       0                  0
# 4                  1         79084.10       0                  0
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0                  0
# 9996               1        101699.77       0                  0
# 9997               1         42085.58       1                  0
# 9998               0         92888.52       1                  1
# 9999               0         38190.78       0                  0
#
#       Geography_Spain
# 0                   0
# 1                   1
# 2                   0
# 3                   0
# 4                   1
# ...               ...
# 9995                0
# 9996                0
# 9997                0
# 9998                0
# 9999                0
#
# [10000 rows x 12 columns]

# %%
df.dtypes
# Out:
# CreditScore            int64
# Gender                 int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_Germany      int64
# Geography_Spain        int64
# dtype: object

# %%
df.Exited
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X = df.drop('Exited', axis=1)
y = df['Exited']

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(sampling_strategy='minority')

X_sm, y_sm = smote.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_sm, y_sm, test_size=0.25,random_state=42, stratify=y_sm)

# %%
X_train.shape
# Out:
# (11944, 11)

# %%
y_train.shape
# Out:
# (11944,)

# %%
X_test
# Out:
#        CreditScore  Gender  Age  Tenure        Balance  NumOfProducts  \
# 929            764       1   24       7  106234.020000              1
# 12969          715       0   40       1       0.000000              2
# 8012           747       1   34      10       0.000000              2
# 2273           726       1   27       7  123826.070000              1
# 4288           577       1   31       4   61211.180000              1
# ...            ...     ...  ...     ...            ...            ...
# 2761           646       0   50       6  145295.310000              2
# 10893          387       0   52       1  152241.498096              1
# 14908          714       0   51       8  137277.046011              1
# 9251           541       1   39       6  109844.810000              1
# 9143           676       1   34       8  100359.540000              1
#
#        HasCrCard  IsActiveMember  EstimatedSalary  Geography_Germany  \
# 929            0               0    115676.380000                  0
# 12969          0               0      2761.107814                  0
# 8012           1               1     50759.800000                  0
# 2273           0               1     78970.580000                  0
# 4288           1               1    145250.430000                  1
# ...          ...             ...              ...                ...
# 2761           1               1     27814.740000                  1
# 10893          1               0    191745.590634                  0
# 14908          0               1      2731.612120                  0
# 9251           1               0     25289.230000                  0
# 9143           0               0     46038.280000                  0
#
#        Geography_Spain
# 929                  0
# 12969                1
# 8012                 0
# 2273                 1
# 4288                 0
# ...                ...
# 2761                 0
# 10893                0
# 14908                0
# 9251                 0
# 9143                 0
#
# [3982 rows x 11 columns]

# %%
history.history.keys
# Out:
# <function dict.keys()>

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (11944, 11)

# %%
model = keras.Sequential([
    keras.layers.Dense(11, input_shape=(X_train.shape[1],), activation='relu'),
    keras.layers.Dense(11, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    validation_split=0.2
)
# Out:
# C:\Users\dell\miniconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.6948 - loss: 0.5894 - val_accuracy: 0.7668 - val_loss: 0.4875
# Epoch 2/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7645 - loss: 0.4907 - val_accuracy: 0.7844 - val_loss: 0.4601
# Epoch 3/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7771 - loss: 0.4710 - val_accuracy: 0.7932 - val_loss: 0.4439
# Epoch 4/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7859 - loss: 0.4552 - val_accuracy: 0.8012 - val_loss: 0.4299
# Epoch 5/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7937 - loss: 0.4417 - val_accuracy: 0.8058 - val_loss: 0.4192
# Epoch 6/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8019 - loss: 0.4303 - val_accuracy: 0.8116 - val_loss: 0.4113
# Epoch 7/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8050 - loss: 0.4235 - val_accuracy: 0.8121 - val_loss: 0.4061
# Epoch 8/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8084 - loss: 0.4188 - val_accuracy: 0.8146 - val_loss: 0.4012
# Epoch 9/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8076 - loss: 0.4160 - val_accuracy: 0.8121 - val_loss: 0.4027
# Epoch 10/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8085 - loss: 0.4135 - val_accuracy: 0.8150 - val_loss: 0.4013
# Epoch 11/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8229 - loss: 0.3898 - val_accuracy: 0.8204 - val_loss: 0.3997
# Epoch 78/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8229 - loss: 0.3897 - val_accuracy: 0.8234 - val_loss: 0.3982
# Epoch 79/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8226 - loss: 0.3899 - val_accuracy: 0.8213 - val_loss: 0.3988
# Epoch 80/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8248 - loss: 0.3894 - val_accuracy: 0.8225 - val_loss: 0.3975
# Epoch 81/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8229 - loss: 0.3891 - val_accuracy: 0.8200 - val_loss: 0.3990
# Epoch 82/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8233 - loss: 0.3890 - val_accuracy: 0.8225 - val_loss: 0.3992
# Epoch 83/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8240 - loss: 0.3885 - val_accuracy: 0.8259 - val_loss: 0.3975
# Epoch 84/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8242 - loss: 0.3892 - val_accuracy: 0.8200 - val_loss: 0.4006
# Epoch 85/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8233 - loss: 0.3886 - val_accuracy: 0.8200 - val_loss: 0.3999
# Epoch 86/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8251 - loss: 0.3890 - val_accuracy: 0.8188 - val_loss: 0.3988
# Epoch 87/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8241 - loss: 0.3882 - val_accuracy: 0.8208 - val_loss: 0.3991
# Epoch 88/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8244 - loss: 0.3883 - val_accuracy: 0.8234 - val_loss: 0.3978
# Epoch 89/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8266 - loss: 0.3878 - val_accuracy: 0.8188 - val_loss: 0.3975
# Epoch 90/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8233 - loss: 0.3879 - val_accuracy: 0.8162 - val_loss: 0.4010
# Epoch 91/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8248 - loss: 0.3880 - val_accuracy: 0.8204 - val_loss: 0.3986
# Epoch 92/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8237 - loss: 0.3876 - val_accuracy: 0.8183 - val_loss: 0.4002
# Epoch 93/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8234 - loss: 0.3879 - val_accuracy: 0.8229 - val_loss: 0.3992
# Epoch 94/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8245 - loss: 0.3875 - val_accuracy: 0.8196 - val_loss: 0.3979
# Epoch 95/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8252 - loss: 0.3874 - val_accuracy: 0.8250 - val_loss: 0.3963
# Epoch 96/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8261 - loss: 0.3875 - val_accuracy: 0.8217 - val_loss: 0.3992
# Epoch 97/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8264 - loss: 0.3875 - val_accuracy: 0.8229 - val_loss: 0.3974
# Epoch 98/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8231 - loss: 0.3878 - val_accuracy: 0.8192 - val_loss: 0.3999
# Epoch 99/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8264 - loss: 0.3872 - val_accuracy: 0.8204 - val_loss: 0.3992
# Epoch 100/100
# 299/299 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8251 - loss: 0.3869 - val_accuracy: 0.8196 - val_loss: 0.3982

# %%
model.evaluate(X_test, y_test)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8009 - loss: 0.4214
# [0.4213851988315582, 0.8008538484573364]

# %%
y_pred = model.predict(X_test)

y_pred = (y_pred > 0.5).astype(int)
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_test
# Out:
# 929      0
# 12969    1
# 8012     0
# 2273     0
# 4288     0
#         ..
# 2761     0
# 10893    1
# 14908    1
# 9251     0
# 9143     0
# Name: Exited, Length: 3982, dtype: int64

# %% [raw]
# print(y_pred)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1642  349]
#  [ 444 1547]]

# %%
sns.heatmap(cm , annot=True, fmt='d', cmap='Blues', xticklabels=['Not churn', 'Churn'], yticklabels=['Not churn', 'Churn'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.82      0.81      1991
#            1       0.82      0.78      0.80      1991
#
#     accuracy                           0.80      3982
#    macro avg       0.80      0.80      0.80      3982
# weighted avg       0.80      0.80      0.80      3982

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Train', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Train', 'Validation'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
